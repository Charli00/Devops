# %%
a=10
b=8
a<=b
# Out:
# False

# %%
n=5
##uper pryamid
for i in range(1,n+1):
    for j in range(n-1):
        print(" ",end=" ")
    for k in range(i):
        print("*",end=" ")
    print()
# Out:
#     *
#     **
#     ***
#     ****
#     *****

# %%
print('hello world')
# Out:
# hello world
