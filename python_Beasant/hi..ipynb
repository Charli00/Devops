# %%
a=10
b=8
a<=b
# Out:
# False

# %%
print('hello world')
# Out:
# hello world
# Bad pipe message: %s [b'0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7\r\nHost: localhost:44727\r\nUs', b'-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.']
# Bad pipe message: %s [b'0.0 Safari/537.36\r\nAccept-Encoding: gzip, defla']
# Bad pipe message: %s [b', br, zstd\r\nAccept-Language: en-US,en;q=0.9,ta;q=0.8\r\nCache-Control: max-age=0\r\nReferer: https://github.com/\r\nX-Req', b'st-ID: 91e7e03b22b911423fa8e448b149a3ec\r\nX-Real-IP: 49.206.28.167\r\nX-Forwarded-Port: 443\r\nX-Forwarded-Scheme: https\r', b'-Original']
# Bad pipe message: %s [b'RI: /\r\nX-Scheme: https\r\nsec-fetch-site: cros', b'site\r\nsec-fetch-mode: navigate\r\nsec-fetch-dest: document\r\nsec-ch-ua: "Not:A-Brand";v="99", "Google Chrome";v="145"', b'"Chromium";v="145"\r\nsec-ch-ua-mobile: ?0\r\ns']
# ...
